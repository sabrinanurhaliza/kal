# %% [markdown]
# # PERSAMAAN 3 VARIABEL
#
# ##### Menghitung Invers yang hasilnya 1, 0, 0
# ###### Diketahui 3 persamaan:
# $\begin{aligned}
#     2x + 3y + z = 5 \\
#     4x + y + 2z = 6 \\
#     3x + 2y + 3z = 7
# \end{aligned}$
#
# ###### Penyelesaian
# 1. Menyusun Matriks Augmentasi [A | I]
# Gabungkan A dengan matriks identitas:
#
# $\begin{bmatrix}
# 2 & 3 & 1 & | & 1 & 0 & 0 \\
# 4 & 1 & 2 & | & 0 & 1 & 0 \\
# 3 & 2 & 3 & | & 0 & 0 & 1
# \end{bmatrix}$
#
# 2. Eliminasi untuk Membentuk Matriks Identitas
#
# Kita akan melakukan operasi baris hingga bagian kiri menjadi matriks identitas.
#
# Langkah 1: Buat elemen (1,1) menjadi 1
# Bagi baris pertama dengan 2:
#
# Hasilnya:
# $\begin{bmatrix}
# 1 & 1.5 & 0.5 & | & 0.5 & 0 & 0 \\
# 4 & 1 & 2 & | & 0 & 1 & 0 \\
# 3 & 2 & 3 & | & 0 & 0 & 1
# \end{bmatrix}$
#
# Langkah 2: Eliminasi elemen di bawah (1,1) menjadi nol
#
# Operasi:
#
# Baris kedua: R2 ← R2 − 4R1
#
# Baris ketiga: R3 ← R3​ − 3R1
#
# Hasilnya:
# $\begin{bmatrix}
# 1 & 1.5 & 0.5 & | & 0.5 & 0 & 0 \\
# 0 & -5 & 0 & | & -2 & 1 & 0 \\
# 0 & -2.5 & 1.5 & | & -1.5 & 0 & 1
# \end{bmatrix}$
#
# Langkah 3: Buat elemen (2,2) menjadi 1
# Bagi baris kedua dengan -5:
#
# Sehingga:
# $\begin{bmatrix}
# 1 & 1.5 & 0.5 & | & 0.5 & 0 & 0 \\
# 0 & 1 & 0 & | & 0.4 & -0.2 & 0 \\
# 0 & -2.5 & 1.5 & | & -1.5 & 0 & 1
# \end{bmatrix}$
#
# Langkah 4: Eliminasi elemen di atas dan bawah (2,2) menjadi nol
#
# Operasi:
#
# Baris kedua: R1 ← R1 − 1.5R2
#
# Baris ketiga: R3 ← R3​ − 2.5R2
#
# Sehingga:
# $\begin{bmatrix}
# 1 & 0 & 0.5 & | & -0.1 & 0.3 & 0 \\
# 0 & 1 & 0 & | & 0.4 & -0.2 & 0 \\
# 0 & 0 & 1.5 & | & -0.5 & -0.5 & 1
# \end{bmatrix}$
#
# Langkah 5: Buat elemen (3,3) menjadi 1
#
# Bagi baris ketiga dengan 1.5:
#
# Sehingga:
# $\begin{bmatrix}
# 1 & 0 & 0.5 & | & -0.1 & 0.3 & 0 \\
# 0 & 1 & 0 & | & 0.4 & -0.2 & 0 \\
# 0 & 0 & 1 & | & -1/3 & -1/3 & 2/3
# \end{bmatrix}$
#
# Langkah 6: Eliminasi elemen di atas (3,3) menjadi nol
#
# Operasi:
#
# Baris pertama: 𝑅1 ← 𝑅1 − 0.5𝑅3
#
# Sehingga:
# $\begin{bmatrix}
# 1 & 0 & 0 & | & -1/3 & 1/3 & -1/3 \\
# 0 & 1 & 0 & | & 0.4 & -0.2 & 0 \\
# 0 & 0 & 1 & | & -1/3 & -1/3 & 2/3
# \end{bmatrix}$
#
# Bagian kiri sekarang adalah matriks identitas, sehingga bagian kanan adalah 𝐴−1.
#
# Hitung elemen-elemennya sehingga hasil akhir menjadi
#
# $\begin{bmatrix}
# 1 \\
# 0 \\
# 0
# \end{bmatrix}$
